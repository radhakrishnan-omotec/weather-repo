# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /kaggle/input/weather-prediction/weather_prediction_dataset.csv
# /kaggle/input/weather-prediction/metadata.txt
# /kaggle/input/weather-prediction/weather_prediction_bbq_labels.csv

# %% [markdown]
# **Weather Prediction Data Set**
#
# - samples collection: daily registrations of the weather from 2000 to 2010
# - the observations took place in 14 cities (in my model I'm focused just on Budapest)
# - 11 analised features: *month number, cloud cover, wind direction, wind speed, wind gust, humidity, sea level pressure, radiation, sunshine, mean, max outdoor temperature*
# - labels describes if it's possible to make the outdoor bbq this day or not

# %%
# Reading weather dataset
df = pd.read_csv('/kaggle/input/weather-prediction/weather_prediction_dataset.csv')
labels = pd.read_csv('/kaggle/input/weather-prediction/weather_prediction_bbq_labels.csv')

# %% [markdown]
# - DataFrame with samples for every city

# %%
# DataFrame of the dataset
df.head(4)
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0  20000101      1                  8            0.89          1.0286
# 1  20000102      1                  8            0.87          1.0318
# 2  20000103      1                  5            0.81          1.0314
# 3  20000104      1                  7            0.79          1.0262
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# 0                    0.20                 0.03             0.0
# 1                    0.25                 0.00             0.0
# 2                    0.50                 0.00             3.7
# 3                    0.63                 0.35             6.9
#
#    BASEL_temp_mean  BASEL_temp_min  ...  STOCKHOLM_temp_min  \
# 0              2.9             1.6  ...                -9.3
# 1              3.6             2.7  ...                 0.5
# 2              2.2             0.1  ...                -1.0
# 3              3.9             0.5  ...                 2.5
#
#    STOCKHOLM_temp_max  TOURS_wind_speed  TOURS_humidity  TOURS_pressure  \
# 0                 0.7               1.6            0.97          1.0275
# 1                 2.0               2.0            0.99          1.0293
# 2                 2.8               3.4            0.91          1.0267
# 3                 4.6               4.9            0.95          1.0222
#
#    TOURS_global_radiation  TOURS_precipitation  TOURS_temp_mean  \
# 0                    0.25                 0.04              8.5
# 1                    0.17                 0.16              7.9
# 2                    0.27                 0.00              8.1
# 3                    0.11                 0.44              8.6
#
#    TOURS_temp_min  TOURS_temp_max
# 0             7.2             9.8
# 1             6.6             9.2
# 2             6.6             9.6
# 3             6.4            10.8
#
# [4 rows x 165 columns]

# %%
# DF informations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Columns: 165 entries, DATE to TOURS_temp_max
# dtypes: float64(150), int64(15)
# memory usage: 4.6 MB

# %% [markdown]
# - DataFrame with labels

# %%
# DataFrame with labels
labels.head(4)
# Out:
#        DATE  BASEL_BBQ_weather  BUDAPEST_BBQ_weather  DE_BBQ_weather  \
# 0  20000101              False                 False           False
# 1  20000102              False                 False           False
# 2  20000103              False                 False           False
# 3  20000104              False                 False           False
#
#    DRESDEN_BBQ_weather  DUSSELDORF_BBQ_weather  HEATHROW_BBQ_weather  \
# 0                False                   False                 False
# 1                False                   False                 False
# 2                False                   False                 False
# 3                False                   False                 False
#
#    KASSEL_BBQ_weather  LJUBLJANA_BBQ_weather  MAASTRICHT_BBQ_weather  \
# 0               False                  False                   False
# 1               False                  False                   False
# 2               False                  False                   False
# 3               False                  False                   False
#
#    MALMO_BBQ_weather  MONTELIMAR_BBQ_weather  MUENCHEN_BBQ_weather  \
# 0              False                   False                 False
# 1              False                   False                 False
# 2              False                   False                 False
# 3              False                   False                 False
#
#    OSLO_BBQ_weather  PERPIGNAN_BBQ_weather  SONNBLICK_BBQ_weather  \
# 0             False                  False                  False
# 1             False                  False                  False
# 2             False                  False                  False
# 3             False                  False                  False
#
#    STOCKHOLM_BBQ_weather  TOURS_BBQ_weather
# 0                  False              False
# 1                  False              False
# 2                  False              False
# 3                  False              False

# %% [markdown]
# - Checking missing values

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3654 entries, 0 to 3653
# Columns: 165 entries, DATE to TOURS_temp_max
# dtypes: float64(150), int64(15)
# memory usage: 4.6 MB

# %% [markdown]
# After dropping rows with missing values, it's the same number of samples as before, so the dataset was complete
#
# **Data Analisys for BUDAPEST**

# %%
# Data analisys for BUDAPEST
df_budapest = pd.concat([df.iloc[:,:2],df.iloc[:,11:19]],axis=1)
df_budapest['DATE'] = pd.to_datetime(df_budapest['DATE'],format='%Y%m%d')

# %%
# Function to count mean values for the features
def mean_for_mth(feature):
    mean = []
    for x in range(12):
        mean.append(
            float("{:.2f}".format(df_budapest[df_budapest['MONTH'] == (x+1)][feature].mean())))
    return mean

# %%
df_budapest.drop(['MONTH'],axis=1).describe()
# Out:
#        BUDAPEST_cloud_cover  BUDAPEST_humidity  BUDAPEST_pressure  \
# count           3654.000000        3654.000000        3654.000000
# mean               4.890531           0.656505           1.016935
# std                2.386442           0.149603           0.007795
# min                0.000000           0.260000           0.989100
# 25%                3.000000           0.540000           1.012100
# 50%                5.000000           0.650000           1.016500
# 75%                7.000000           0.770000           1.021475
# max                8.000000           1.000000           1.043800
#
#        BUDAPEST_global_radiation  BUDAPEST_precipitation  BUDAPEST_sunshine  \
# count                3654.000000             3654.000000        3654.000000
# mean                    1.465487                0.136442           5.753229
# std                     0.977986                0.408932           4.475439
# min                     0.040000                0.000000           0.000000
# 25%                     0.580000                0.000000           1.100000
# 50%                     1.340000                0.000000           5.900000
# 75%                     2.310000                0.030000           9.600000
# max                     3.490000                6.960000          14.900000
#
#        BUDAPEST_temp_mean  BUDAPEST_temp_max
# count         3654.000000        3654.000000
# mean            12.174849          16.629091
# std              8.744451           9.981538
# min             -9.800000          -6.600000
# 25%              5.100000           8.400000
# 50%             12.800000          17.400000
# 75%             19.300000          25.000000
# max             33.100000          40.100000

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(12,6))
plt.plot(df_budapest['DATE'][:365],df_budapest['BUDAPEST_temp_mean'][:365])
plt.title('Temperature in 2000')
plt.xlabel('DATE')
plt.ylabel('DEGREE')
# Out:
# Text(0, 0.5, 'DEGREE')

# %%
months = ['Jan', 'Febr', 'Mar', 'Apr', 'May', 'Jun', 'Jul',
          'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
mean_temp = mean_for_mth('BUDAPEST_temp_mean')
sns.set(style="darkgrid")
plt.figure(figsize=(12,6))
bar = plt.bar(x = months,height = mean_temp, width = 0.8, color=['thistle','mediumaquamarine',                'orange'])
plt.xticks(rotation = 45)
plt.xlabel('MONTHS')
plt.ylabel('DEGREES')
plt.title('Mean Temperature during the year in BUDAPEST')
plt.bar_label(bar)
# Out:
# [Text(0, 0, '0.85'),
#  Text(0, 0, '2.78'),
#  Text(0, 0, '6.91'),
#  Text(0, 0, '13.13'),
#  Text(0, 0, '18.03'),
#  Text(0, 0, '20.97'),
#  Text(0, 0, '22.67'),
#  Text(0, 0, '22.37'),
#  Text(0, 0, '16.98'),
#  Text(0, 0, '12.42'),
#  Text(0, 0, '6.94'),
#  Text(0, 0, '1.57')]

# %%
sns.set(style="darkgrid")
mean_temp = mean_for_mth('BUDAPEST_humidity')
plt.figure(figsize=(12,6))
bar = plt.bar(x = months, height = mean_temp, width = 0.8, color=['thistle','mediumaquamarine',                'orange'])
plt.xticks(rotation = 45)
plt.xlabel('MONTHS')
plt.ylabel('HUMIDITY')
plt.title('Mean Humidity during the year in BUDAPEST')
plt.bar_label(bar)
# Out:
# [Text(0, 0, '0.77'),
#  Text(0, 0, '0.71'),
#  Text(0, 0, '0.64'),
#  Text(0, 0, '0.55'),
#  Text(0, 0, '0.56'),
#  Text(0, 0, '0.57'),
#  Text(0, 0, '0.58'),
#  Text(0, 0, '0.59'),
#  Text(0, 0, '0.64'),
#  Text(0, 0, '0.72'),
#  Text(0, 0, '0.77'),
#  Text(0, 0, '0.79')]

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(2, 2, figsize=(12,8))
fig.suptitle('Vertically stacked subplots')
sns.histplot(data = df_budapest, x ='BUDAPEST_pressure', ax=axs[0,0], color='red', kde=True)
sns.histplot(data = df_budapest, x ='BUDAPEST_humidity', ax=axs[0,1], color='orange', kde=True)
sns.histplot(data = df_budapest, x ='BUDAPEST_temp_mean', ax=axs[1,0], kde=True)
sns.histplot(data = df_budapest, x ='BUDAPEST_global_radiation', ax=axs[1,1], color='green', kde=True)
# Out:
# <AxesSubplot:xlabel='BUDAPEST_global_radiation', ylabel='Count'>

# %%
labels_budapest = labels['BUDAPEST_BBQ_weather']
sns.set(style="darkgrid")
plt.figure(figsize=(12,6))
sns.countplot(x = labels_budapest).set(title='Labels for BUDAPEST')
# Out:
# [Text(0.5, 1.0, 'Labels for BUDAPEST')]

# %%
true_val = len(labels_budapest[labels_budapest == True])
false_val = len(labels_budapest[labels_budapest == False])
print('Precent of True values: {0:.2f}%'.format(true_val/(true_val+false_val)*100))
print('Precent of False values: {0:.2f}%'.format(false_val/(true_val+false_val)*100))
# Out:
# Precent of True values: 36.75%
# Precent of False values: 63.25%

# %%
labels_budapest = labels_budapest.astype(int)
plt.figure(figsize=(12,6))
sns.set(style="darkgrid")
sns.boxplot(y = df_budapest['BUDAPEST_temp_mean'], x = labels_budapest).set(title='Relation between the temperature and the bbq weather')
# Out:
# [Text(0.5, 1.0, 'Relation between the temperature and the bbq weather')]

# %% [markdown]
# - The dataset for Budapest is imbalanced, it's almost 2x more samples with False labels

# %%
# Oversampling the dataset
labels_budapest = labels_budapest.astype(int)
df_budapest = df_budapest.drop(['DATE'],axis=1)
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler()
ovrspl_X, ovrspl_y  = oversample.fit_resample(df_budapest, labels_budapest)

# %%
labels_budapest = labels['BUDAPEST_BBQ_weather']
sns.set(style="darkgrid")
plt.figure(figsize=(12,6))
sns.countplot(x = ovrspl_y).set(title='Oversampled Labels for BUDAPEST')
# Out:
# [Text(0.5, 1.0, 'Oversampled Labels for BUDAPEST')]

# %%
true_val = len(ovrspl_y[ovrspl_y == 1])
false_val = len(ovrspl_y[ovrspl_y == 0])
print('Precent of True values: {0:.1f}%'.format(true_val/(true_val+false_val)*100))
print('Precent of False values: {0:.1f}%'.format(false_val/(true_val+false_val)*100))
# Out:
# Precent of True values: 50.0%
# Precent of False values: 50.0%

# %% [markdown]
# - After using RandomOverSampler I received the same number of labels

# %%
plt.figure(figsize=(12,6))
sns.set(style="darkgrid")
sns.heatmap(df_budapest.corr(),annot=True,cmap='coolwarm').set(title='Correlation between features')
# Out:
# [Text(0.5, 1.0, 'Correlation between features')]

# %% [markdown]
# - it's a high correlation between global radiation and sunshine, mean and max temperature
# - it's almost full correlation between mean and max temperature
# - it's high inverse correlation between sunshine and humidity, sunshine and cloud cover, global radiation and humidity
#
# **Data normalisation**

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
norm_X = scaler.fit_transform(ovrspl_X)
norm_X = pd.DataFrame(norm_X, columns=df_budapest.columns)
norm_X.describe()
# Out:
#              MONTH  BUDAPEST_cloud_cover  BUDAPEST_humidity  \
# count  4622.000000           4622.000000        4622.000000
# mean      0.507553              0.575076           0.503853
# std       0.289777              0.296336           0.201885
# min       0.000000              0.000000           0.000000
# 25%       0.272727              0.375000           0.351351
# 50%       0.545455              0.625000           0.486486
# 75%       0.727273              0.875000           0.648649
# max       1.000000              1.000000           1.000000
#
#        BUDAPEST_pressure  BUDAPEST_global_radiation  BUDAPEST_precipitation  \
# count        4622.000000                4622.000000             4622.000000
# mean            0.506143                   0.468285                0.015498
# std             0.133246                   0.286526                0.052845
# min             0.000000                   0.000000                0.000000
# 25%             0.425960                   0.197101                0.000000
# 50%             0.499086                   0.476812                0.000000
# 75%             0.579525                   0.727536                0.000000
# max             1.000000                   1.000000                1.000000
#
#        BUDAPEST_sunshine  BUDAPEST_temp_mean  BUDAPEST_temp_max
# count        4622.000000         4622.000000        4622.000000
# mean            0.439959            0.551328           0.538831
# std             0.303312            0.201471           0.211041
# min             0.000000            0.000000           0.000000
# 25%             0.140940            0.391608           0.368844
# 50%             0.469799            0.588578           0.573876
# 75%             0.697987            0.708625           0.706638
# max             1.000000            1.000000           1.000000

# %%
from sklearn.model_selection import train_test_split
# Splitting dataset on training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(ovrspl_X,ovrspl_y, test_size = 0.3, random_state = 42)
print('Training set: ' + str(len(X_train)))
print('Testing set: ' + str(len(X_test)))
# Out:
# Training set: 3235
# Testing set: 1387

# %% [markdown]
# **SVC Model**
# - using the Support Vector Machine to weather predictions
# - the kernel is linear

# %%
from sklearn.svm import SVC

model = SVC(verbose=True, kernel = 'linear', random_state = 0)
model.fit(X_train,y_train)
# Out:
# [LibSVM]...........................*..............*...................................*
# optimization finished, #iter = 76188
# obj = -571.568004, rho = -3.404254
# nSV = 637, nBSV = 625
# Total nSV = 637
# SVC(kernel='linear', random_state=0, verbose=True)

# %%
y_predict = model.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print('Classification report--------------------------------')
print(classification_report(y_test,y_predict))
sns.heatmap(confusion_matrix(y_test,y_predict), annot=True, fmt='g').set(title='Confusion Matrix')
# Out:
# Classification report--------------------------------
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.95       712
#            1       0.92      0.99      0.95       675
#
#     accuracy                           0.95      1387
#    macro avg       0.95      0.95      0.95      1387
# weighted avg       0.95      0.95      0.95      1387
# [Text(0.5, 1.0, 'Confusion Matrix')]

# %%
print('Model accuracy is: {0:.2f}%'.format(accuracy_score(y_test, y_predict)*100))
# Out:
# Model accuracy is: 95.03%
